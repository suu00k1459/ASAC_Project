# %%
# !pip install opencv-contrib-python
# !pip install --upgrade google-cloud-vision
# !pip install utils
# Out:
# Requirement already satisfied: opencv-contrib-python in /opt/anaconda3/lib/python3.11/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.11/site-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: google-cloud-vision in /opt/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.19.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-vision) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-vision) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-vision) (4.25.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.63.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.62.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2024.2.2)
# Requirement already satisfied: utils in /opt/anaconda3/lib/python3.11/site-packages (1.0.2)

# %%
import os
import io
import re
import math

import numpy as np
import pandas as pd

from PIL import ImageFont, ImageDraw, Image
import platform
import matplotlib as plt
# from utils import plt_imshow
from PIL import Image
import cv2
from google.cloud import vision

# %%
# 이미지 확인용 ( 데이터 만들 때는 필요 없음)
def plt_imshow(title='image', img=None, figsize=(8 ,5)):
    plt.figure(figsize=figsize)
 
    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []
 
            for i in range(len(img)):
                titles.append(title)
 
        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)
 
            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])
 
        plt.show()
    else:
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()

# %%
# 글자 인식
def putText(image, text, x, y, color=(0, 255, 0), font_size=22):
    if type(image) == np.ndarray:
        color_coverted = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # 이미지 전처리
        image = Image.fromarray(color_coverted)
 
    if platform.system() == 'Darwin':
        font = 'AppleGothic.ttf'
    elif platform.system() == 'Windows':
        font = 'malgun.ttf'
    else:
        font = 'NanumGothic.ttf' # 안될 경우) 해당 글씨체 있는지 확인해보기
        
    image_font = ImageFont.truetype(font, font_size)
    font = ImageFont.load_default()
    draw = ImageDraw.Draw(image)
 
    draw.text((x, y), text, font=image_font, fill=color)
    
    numpy_image = np.array(image)
    opencv_image = cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)
 
    return opencv_image

# %%
# 임의의 사각형을 이루는 각 변의 벡터 계산
def calculate_polygon_area(vertices):    
    vectors = []
    
    for i in range(len(vertices)):
        x1, y1 = vertices[i]
        x2, y2 = vertices[(i + 1) % len(vertices)]
        vectors.append((x2 - x1, y2 - y1))
        
    # 외적을 통한 넓이 계산
    area = 0
    for i in range(len(vectors)):
        area += vectors[i][0] * vectors[(i + 1) % len(vectors)][1]
        area -= vectors[i][1] * vectors[(i + 1) % len(vectors)][0]

    area = abs(area) / 2
    return area

# %%
# 이미지 크기 계산 : 경로 설정 필요함!
def size(img):
    im = Image.open("/Users/jihoonlee/Desktop/ASAC/ML/MLproject/movie_poster"+"/"+img) # 여기
    width, height = im.size
    
    return width*height

# %%
# 특수문자 제거 정규식 (안 썼음)
def remove_special_characters(text):
    result = re.sub(r'[^\w\s]', '-', text)
    result = re.sub(r'[-\*]', '', text)
    
    return result

# %%
# 구글 클라우드 연동!
# 키 값 입력 필요함!

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/Users/jihoonlee/Desktop/ASAC/ML/MLproject/service_secret_key.json" # 키
 
client_options = {'api_endpoint': 'eu-vision.googleapis.com'}
client = vision.ImageAnnotatorClient(client_options=client_options)

# %%
def make_list(directory,i,image_index, str_idx, end_idx):
    #i -> movie_idx -> 영화순서
    
    lst=[]   
    
    for image_name, index in image_index.items():
        print("<",index,image_name,">") #진행상황 확인용 프린트
        
        path=directory+"/"+image_name
        
        with io.open(path, 'rb') as image_file:
            content = image_file.read()
        
        client = vision.ImageAnnotatorClient()
        
        # 이미지 컨텐츠 설정
        image = vision.Image(content=content)
        
        # 이미지 컨텍스트 설정 (언어 힌트 추가)
        image_context = vision.ImageContext(language_hints=["ko"])
        
        # 텍스트 감지 요청
        response = client.text_detection(image=image, image_context=image_context)
        texts = response.text_annotations
        
            # texts 에서 글자 이상한 거 여기서 없애기!
            # texts = remove_special_characters(texts[0].description)
            
        poster_size = size(image_name)
            
        for idx, text in enumerate(texts):
            vertices = [(vertex.x, vertex.y) for vertex in text.bounding_poly.vertices]
            box_size = calculate_polygon_area(vertices)
                
            temp = []
                
            temp.append(i) #영화 인덱스
            temp.append(os.path.splitext(image_name)[0]) # 영화 이름
            temp.append(poster_size) # 포스터 전체 사이즈
            temp.append(idx)
            temp.append(text.description) #인식한 단어
            temp.append(len(text.description)) #인식한 단어 전체 길이(한 음절 기준)
            temp.append(vertices[0]) #좌표 좌측 하단
            temp.append(vertices[1]) #좌표 우측 하단
            temp.append(vertices[2]) #좌표 우측 상단
            temp.append(vertices[3]) #좌표 좌측 상단
            temp.append(calculate_polygon_area(vertices)) #단어 상자 크기_ 글자 크기로 간주
            temp.append(box_size/poster_size) # 전체 포스터 대비 단어 상자별 비율

                
            lst.append(temp)
        i=i+1

    return lst
    
#         맥에서 안될 때 사용해보기
# for text in texts:
#     print('\n"{}"'.format(text.description))
#     vertices = [(vertex.x, vertex.y) for vertex in text.bounding_poly.vertices]
#     print('텍스트 위치: {}'.format(vertices))

# %%
# 경로 설정 후 포스터 리스트 받기
directory = "/Users/jihoonlee/Desktop/ASAC/ML/MLproject/movie_poster" # 여기
files = sorted(os.listdir(directory))
image_index = {}

# # 파일 목록을 순회하며 이미지 파일인지 확인하고 인덱스 부여
for index, file in enumerate(files):
    file_extension = os.path.splitext(file)[1].lower()
    if file_extension in ['.jpg']:
        image_index[file] = index
    print(file)
# Out:
# 1947 보스톤.jpg
# 1980.jpg
# 1986 그 여름, 그리고 고등어통조림.jpg
# 2022 영탁 단독 콘서트 -탁쇼-.jpg
# 3000년의 기다림.jpg
# 30일.jpg
# 355.jpg
# 3일의 휴가.jpg
# 65.jpg
# 6번 칸.jpg
# 80일간의 세계일주.jpg
# 9명의 번역가.jpg
# B컷.jpg
# DC 리그 오브 슈퍼-펫.jpg
# DMZ 동물 특공대.jpg
# TAR 타르.jpg
# 가가린.jpg
# 클리포드 더 빅 레드 독.jpg
# 키리에의 노래.jpg
# 킬링 로맨스.jpg
# 킴스 비디오.jpg
# 킹 리차드.jpg
# 킹덤 3- 운명의 불꽃.jpg
# 킹덤2- 아득한 대지로.jpg
# 킹메이커.jpg
# 킹스맨- 퍼스트 에이전트.jpg
# 타겟.jpg
# 탄생.jpg
# 탐정 말로.jpg
# 탑.jpg
# 탑건- 매버릭.jpg
# 태어나길 잘했어.jpg
# 태일이.jpg
# 테일러 스위프트 디 에라스 투어.jpg
# 토르- 러브 앤 썬더.jpg
# 토르- 마법 검의 전설.jpg
# 토리와 로키타.jpg
# 톡 투 미.jpg
# 트랜스포머- 비스트의 서막.jpg
# 트롤- 밴드 투게더.jpg
# 트윈.jpg
# 특송.jpg
# 특수요원 빼꼼.jpg
# 티처스 라운지.jpg
# 티켓 투 파라다이스.jpg
# 틴에이지 크라켄 루비.jpg
# 틸.jpg
# 파라다이스 하이웨이.jpg
# 파리, 13구.jpg
# 파묘.jpg
# 파벨만스.jpg
# 파이어하트.jpg
# 패러렐 마더스.jpg
# 패스트 라이브즈.jpg
# 퍼스트 러브.jpg
# 퍼피 구조대- 더 마이티 무비.jpg
# 페르시아어 수업.jpg
# 폭로.jpg
# 폴- 600미터.jpg
# 풀타임.jpg
# 풍재기시.jpg
# 프랑스.jpg
# 프레디의 피자가게.jpg
# 프레이 포 더 데블.jpg
# 프로메어.jpg
# 프리! 더 파이널 스트로크 전편.jpg
# 프리! 더 파이널 스트로크 후편.jpg
# 프린세스 아야.jpg
# 프린스 챠밍.jpg
# 플라워 킬링 문.jpg
# 플래닛.jpg
# 플래시.jpg
# 플랜 75.jpg
# 플레인.jpg
# 플로라 앤 썬.jpg
# 피그.jpg
# 피는 물보다 진하다.jpg
# 핑크퐁 시네마 콘서트 2- 원더스타 콘서트 대작전.jpg
# 핑크퐁 시네마 콘서트3 - 진저브레드맨을 잡아라.jpg
# 하늘의 푸르름을 아는 사람이여.jpg
# 하우스 오브 구찌.jpg
# 한 남자.jpg
# 한산 리덕스.jpg
# 한산- 용의 출현.jpg
# 한여름밤의 재즈.jpg
# 항구의 니쿠코짱!.jpg
# 해시태그 시그네.jpg
# 해적- 도깨비 깃발.jpg
# 해탄적일천.jpg
# 해피 뉴 이어.jpg
# 헌트.jpg
# 헌티드 맨션.jpg
# 헝거게임- 노래하는 새와 뱀의 발라드.jpg
# 헤어질 결심.jpg
# 헤이지니&럭키강이 비밀의 문.jpg
# 홈그라운드.jpg
# 홈리스.jpg
# 화녀.jpg
# 화란.jpg
# 화사한 그녀.jpg
# 화이트 노이즈.jpg
# 힐마 아프 클린트 - 미래를 위한 그림.jpg
# 힙노틱.jpg

# %%
# 1 => moive_idx 시작점
lst= make_list(directory,1,image_index,math.floor(len(image_index)/2),len(image_index))
# Out:
# < 0 1947 보스톤.jpg >
# < 1 1980.jpg >
# < 2 1986 그 여름, 그리고 고등어통조림.jpg >
# < 3 2022 영탁 단독 콘서트 -탁쇼-.jpg >
# < 126 넥스트 골 윈즈.jpg >
# < 127 노 베어스.jpg >
# < 128 노 엑시트.jpg >
# < 129 노량- 죽음의 바다.jpg >
# < 130 노스맨.jpg >
# < 131 노웨어 스페셜.jpg >
# < 132 녹야.jpg >
# < 133 녹턴.jpg >
# < 134 놈이 우리 안에 있다.jpg >
# < 135 놉.jpg >
# < 136 눈의 여왕5- 스노우 프린세스와 미러랜드의 비밀.jpg >
# < 137 뉴 노멀.jpg >
# < 138 늑대사냥.jpg >
# < 139 니 부모 얼굴이 보고 싶다.jpg >
# < 140 니얼굴.jpg >
# < 141 닌자터틀- 뮤턴트 대소동.jpg >
# < 142 다 잘된 거야.jpg >
# < 143 다음 소희.jpg >
# < 144 다이브- 100 피트 추락.jpg >
# < 145 닥터 스트레인지- 대혼돈의 멀티버스.jpg >
# < 146 단순한 열정.jpg >
# < 147 달짝지근해- 7510.jpg >
# < 148 대결! 애니메이션.jpg >
# < 149 대니초 - 코리안 드림.jpg >
# < 150 대무가.jpg >
# < 151 대외비.jpg >
# < 152 댓글부대.jpg >
# < 153 더 넌 2.jpg >
# < 154 더 노비스.jpg >
# < 155 더 마블스.jpg >
# < 156 더 메뉴.jpg >
# < 157 더 문.jpg >
# < 158 더 배트맨.jpg >
# < 159 더 썬.jpg >
# < 160 더 와일드- 야수들의 전쟁.jpg >
# < 161 더 웨일.jpg >
# < 162 더 컨트랙터.jpg >
# < 163 더 킬러- 죽어도 되는 아이.jpg >
# < 164 더 킬러.jpg >
# < 165 더 퍼스트 슬램덩크.jpg >
# < 166 던전 앤 드래곤- 도적들의 명예.jpg >
# < 167 덤 머니.jpg >
# < 168 데드맨.jpg >
# < 169 데시벨.jpg >
# < 170 도그데이즈.jpg >
# < 171 도그맨.jpg >
# < 172 도어맨.jpg >
# < 173 도쿄 리벤저스.jpg >
# < 174 도티와 영원의 탑.jpg >
# < 175 돌핀.jpg >
# < 176 돌핀보이.jpg >
# < 177 동감.jpg >
# < 178 두 사람을 위한 식탁.jpg >
# < 179 두다다쿵- 후후섬의 비밀.jpg >
# < 180 둠둠.jpg >
# < 181 뒤틀린 집.jpg >
# < 182 듄- 파트2.jpg >
# < 183 드라이.jpg >
# < 184 드라이브 마이 카.jpg >
# < 185 드래곤볼 슈퍼- 슈퍼 히어로.jpg >
# < 186 드림.jpg >
# < 187 드림쏭2.jpg >
# < 188 드림쏭3.jpg >
# < 189 드림팰리스.jpg >
# < 190 듣보인간의 생존신고.jpg >
# < 191 똑똑똑.jpg >
# < 192 뜨거운 피- 디 오리지널.jpg >
# < 193 뜨거운 피.jpg >
# < 194 라방.jpg >
# < 195 라이드 온.jpg >
# < 196 라이스보이 슬립스.jpg >
# < 197 라이즈.jpg >
# < 198 라일 라일 크로커다일.jpg >
# < 199 랜드 오브 배드.jpg >
# < 200 램.jpg >
# < 201 런닝맨- 리벤져스.jpg >
# < 202 레벤느망.jpg >
# < 203 레지던트 이블- 라쿤시티.jpg >
# < 204 레트리뷰션.jpg >
# < 205 렌필드.jpg >
# < 206 로망스 돌.jpg >
# < 207 로보카폴리 안전교실 교통편.jpg >
# < 208 로봇 드림.jpg >
# < 209 로스트 도터.jpg >
# < 210 로스트 시티.jpg >
# < 211 롱디.jpg >
# < 212 루이스 웨인- 사랑을 그린 고양이 화가.jpg >
# < 213 룸 쉐어링.jpg >
# < 214 류이치 사카모토- 오퍼스.jpg >
# < 215 리디밍 러브.jpg >
# < 216 리멤버.jpg >
# < 217 리미트.jpg >
# < 218 리바운드.jpg >
# < 219 리빙- 어떤 인생.jpg >
# < 220 리코리쉬 피자.jpg >
# < 221 립세의 사계.jpg >
# < 222 마녀(魔女) Part2. The Other One.jpg >
# < 223 마담 웹.jpg >
# < 224 마루이 비디오.jpg >
# < 225 마리앙투아네트.jpg >
# < 226 마브카 - 숲의 노래.jpg >
# < 227 마야 3- 숲속 왕국의 위기.jpg >
# < 228 마에스트로 번스타인.jpg >
# < 229 마에스트로.jpg >
# < 230 마이 샤이니 월드.jpg >
# < 231 막걸리가 알려줄거야.jpg >
# < 232 만강홍- 사라진 밀서.jpg >
# < 233 만년이 지나도 변하지 않는 게 있어.jpg >
# < 234 만분의 일초.jpg >
# < 235 만인의 연인.jpg >
# < 236 말없는 소녀.jpg >
# < 237 말임씨를 부탁해.jpg >
# < 238 말하고 싶은 비밀.jpg >
# < 239 매미소리.jpg >
# < 240 매스.jpg >
# < 241 매직 프린세스- 얼음 괴물과 사라진 열쇠의 비밀.jpg >
# < 242 매트릭스- 리저렉션.jpg >
# < 243 멋진 세계.jpg >
# < 244 멍뭉이.jpg >
# < 245 메가로돈 2.jpg >
# < 246 메간.jpg >
# < 247 메리 마이 데드 바디.jpg >
# < 248 메리 미.jpg >
# < 249 메모리아.jpg >
# < 250 메이 디셈버.jpg >
# < 251 멘.jpg >
# < 252 명탐정 코난- 할로윈의 신부.jpg >
# < 253 명탐정코난- 하이바라 아이 이야기 ~흑철의 미스터리 트레인.jpg >
# < 254 명탐정코난- 흑철의 어영.jpg >
# < 255 모나리자와 블러드 문.jpg >
# < 256 모비우스.jpg >
# < 257 모어.jpg >
# < 258 목스박.jpg >
# < 259 몬스터 신부- 101번째 프로포즈.jpg >
# < 260 몬스터 싱어- 매직 인 파리.jpg >
# < 261 몬스터 아카데미.jpg >
# < 262 몬스터 패밀리 2.jpg >
# < 263 몬스터 하우스2- 인비져블 피닉스.jpg >
# < 264 무명.jpg >
# < 265 문맨.jpg >
# < 266 문재인입니다.jpg >
# < 267 문폴.jpg >
# < 268 물방울을 그리는 남자.jpg >
# < 269 뮤지컬 공연실황, 알쏭달쏭 캐치! 티니핑 -신비한 상자를 열어라!-.jpg >
# < 270 뮤지컬 레드북.jpg >
# < 271 뮤지컬 킹키부츠 라이브.jpg >
# < 272 미녀와 야수- 마법에 걸린 왕자.jpg >
# < 273 미니언즈2.jpg >
# < 274 미션 임파서블- 데드 레코닝 PART ONE.jpg >
# < 275 미시즈 해리스 파리에 가다.jpg >
# < 276 미싱타는 여자들.jpg >
# < 415 썬더버드.jpg >
# < 416 썸머 필름을 타고!.jpg >
# < 417 쏘우 X.jpg >
# < 418 쓰리- 아직 끝나지 않았다.jpg >
# < 419 씰벤져스 - 용감한 바다특공대.jpg >
# < 420 씽2게더.jpg >
# < 421 아가일.jpg >
# < 422 아기상어 극장판- 사이렌 스톤의 비밀.jpg >
# < 423 아네모네.jpg >
# < 424 아라시 20주년 투어 콘서트.jpg >
# < 425 아르고 원정대- 꼬마 영웅 패티의 대모험.jpg >
# < 426 아마겟돈 타임.jpg >
# < 427 아머드 사우루스- 기계공룡제국의 침략.jpg >
# < 428 아바타 리마스터링.jpg >
# < 429 아바타- 물의 길.jpg >
# < 430 아버지의 마음.jpg >
# < 431 아이를 위한 아이.jpg >
# < 432 아이엠 티라노.jpg >
# < 433 아이유 콘서트 - 더 골든 아워.jpg >
# < 434 아이의 노랫소리를 들려줘.jpg >
# < 435 아인보- 아마존의 전설.jpg >
# < 436 아임 히어로 더 파이널.jpg >
# < 437 아치의 노래, 정태춘.jpg >
# < 438 아쿠아맨과 로스트 킹덤.jpg >
# < 439 아톰 새로운 시작.jpg >
# < 440 악마들.jpg >
# < 441 악은 존재하지 않는다.jpg >
# < 442 안녕, 소중한 사람.jpg >
# < 443 안녕하세요.jpg >
# < 444 안테벨룸.jpg >
# < 445 알카라스의 여름.jpg >
# < 446 압꾸정.jpg >
# < 447 애니멀 체인지.jpg >
# < 448 애스터로이드 시티.jpg >
# < 449 애프터 미투.jpg >
# < 450 애프터 양.jpg >
# < 451 애프터- 에버 해피.jpg >
# < 452 애프터썬.jpg >
# < 453 앤트맨과 와스프- 퀀텀매니아.jpg >
# < 454 앰뷸런스.jpg >
# < 455 앵커.jpg >
# < 456 약속.jpg >
# < 457 양자경의 더 모든 날 모든 순간.jpg >
# < 458 어나더 라운드.jpg >
# < 459 어느 멋진 아침.jpg >
# < 460 어디로 가고 싶으신가요.jpg >
# < 461 어떤 영웅.jpg >
# < 462 어른 김장하.jpg >
# < 463 어메이징 모리스.jpg >
# < 464 어부바.jpg >
# < 465 어웨이크.jpg >
# < 466 어쩌다 공주, 닭냥이 왕자를 부탁해!.jpg >
# < 467 어쩌면 우린 헤어졌는지 모른다.jpg >
# < 468 어파이어.jpg >
# < 469 언차티드.jpg >
# < 470 엄마.jpg >
# < 471 엄마의 땅- 그리샤와 숲의 주인.jpg >
# < 472 에브리씽 에브리웨어 올 앳 원스+.jpg >
# < 473 에브리씽 에브리웨어 올 앳 원스.jpg >
# < 474 에스파- 마이 퍼스트 페이지.jpg >
# < 475 에어.jpg >
# < 476 에이비식스 - 테이크 어 챈스.jpg >
# < 477 에펠.jpg >
# < 478 에픽하이 20 더 무비.jpg >
# < 479 엑소시스트- 더 바티칸.jpg >
# < 480 엑소시스트- 믿는 자.jpg >
# < 481 엑스칼리버 더 뮤지컬 다큐멘터리- 도겸의 찬란한 여정.jpg >
# < 482 엔니오- 더 마에스트로.jpg >
# < 483 엔드 오브 에반게리온.jpg >
# < 556 자백.jpg >
# < 557 자우림, 더 원더랜드.jpg >
# < 558 잠.jpg >
# < 559 장기자랑.jpg >
# < 560 장민호 드라마 최종회.jpg >
# < 561 장화신은 고양이- 끝내주는 모험.jpg >
# < 562 재춘언니.jpg >
# < 563 전투왕.jpg >
# < 564 정글번치- 월드투어.jpg >
# < 565 정직한 후보2.jpg >
# < 566 제이홉 인 더 박스.jpg >
# < 567 젠틀맨.jpg >
# < 568 조이 라이드.jpg >
# < 569 존 윅 4.jpg >
# < 570 좋.댓.구.jpg >
# < 571 주사위놀이, 마불 세계여행.jpg >
# < 572 죽어도 자이언츠.jpg >
# < 573 쥬라기 월드- 도미니언.jpg >
# < 574 쥬라기캅스 극장판- 공룡시대 대모험.jpg >
# < 575 지오디 마스터피스 더 무비.jpg >
# < 576 지옥만세.jpg >
# < 577 차박- 살인과 낭만의 밤.jpg >
# < 578 창밖은 겨울.jpg >
# < 579 천룡팔부- 교봉전.jpg >
# < 580 천박사 퇴마 연구소- 설경의 비밀.jpg >
# < 581 청춘 돼지는 책가방 소녀의 꿈을 꾸지 않는다.jpg >
# < 582 청춘적니.jpg >
# < 583 체리마호- 30살까지 동정이면 마법사가 될 수 있대.jpg >
# < 584 추락의 해부.jpg >
# < 585 치악산.jpg >
# < 586 치치치 치킨의 비밀.jpg >
# < 587 치치핑핑의 쿵쿵따 탐험대.jpg >
# < 588 치킨래빗- 잃어버린 보물을 찾아서.jpg >
# < 589 카고.jpg >
# < 590 카구야 님은 고백받고 싶어 -첫 키스는 끝나지 않아-.jpg >
# < 591 카시오페아.jpg >
# < 592 카운트.jpg >
# < 593 칸다하.jpg >
# < 594 캐리와 슈퍼콜라.jpg >
# < 595 캐릭터.jpg >
# < 596 컴백홈.jpg >
# < 597 컴온 컴온.jpg >
# < 598 코다.jpg >
# < 599 코르사주.jpg >
# < 600 코코순이.jpg >
# < 601 콘크리트 유토피아.jpg >
# < 602 쿠폰의 여왕.jpg >
# < 603 큐어.jpg >
# < 604 크레센도 반 클라이번 콩쿠르 실황.jpg >
# < 605 크레센도.jpg >
# < 606 크레이지 컴페티션.jpg >
# < 607 크리드 3.jpg >
# < 608 크리스마스 캐럴.jpg >
# < 609 크리에이터.jpg >
# < 610 클럽 제로.jpg >
# < 611 클레오의 세계.jpg >
# < 612 클로즈.jpg >
# < 613 클리포드 더 빅 레드 독.jpg >
# < 614 키리에의 노래.jpg >
# < 615 킬링 로맨스.jpg >
# < 616 킴스 비디오.jpg >
# < 617 킹 리차드.jpg >
# < 618 킹덤 3- 운명의 불꽃.jpg >
# < 619 킹덤2- 아득한 대지로.jpg >
# < 620 킹메이커.jpg >
# < 621 킹스맨- 퍼스트 에이전트.jpg >
# < 622 타겟.jpg >
# < 623 탄생.jpg >
# < 624 탐정 말로.jpg >
# < 625 탑.jpg >
# < 626 탑건- 매버릭.jpg >
# < 627 태어나길 잘했어.jpg >
# < 628 태일이.jpg >
# < 629 테일러 스위프트 디 에라스 투어.jpg >
# < 630 토르- 러브 앤 썬더.jpg >
# < 631 토르- 마법 검의 전설.jpg >
# < 632 토리와 로키타.jpg >
# < 633 톡 투 미.jpg >
# < 634 트랜스포머- 비스트의 서막.jpg >
# < 635 트롤- 밴드 투게더.jpg >
# < 636 트윈.jpg >
# < 637 특송.jpg >
# < 638 특수요원 빼꼼.jpg >
# < 639 티처스 라운지.jpg >
# < 640 티켓 투 파라다이스.jpg >
# < 641 틴에이지 크라켄 루비.jpg >
# < 642 틸.jpg >
# < 643 파라다이스 하이웨이.jpg >
# < 644 파리, 13구.jpg >
# < 645 파묘.jpg >
# < 646 파벨만스.jpg >
# < 647 파이어하트.jpg >
# < 648 패러렐 마더스.jpg >
# < 649 패스트 라이브즈.jpg >
# < 650 퍼스트 러브.jpg >
# < 651 퍼피 구조대- 더 마이티 무비.jpg >
# < 652 페르시아어 수업.jpg >
# < 653 폭로.jpg >
# < 654 폴- 600미터.jpg >
# < 655 풀타임.jpg >
# < 656 풍재기시.jpg >
# < 657 프랑스.jpg >
# < 658 프레디의 피자가게.jpg >
# < 659 프레이 포 더 데블.jpg >
# < 660 프로메어.jpg >
# < 661 프리! 더 파이널 스트로크 전편.jpg >
# < 662 프리! 더 파이널 스트로크 후편.jpg >
# < 663 프린세스 아야.jpg >
# < 664 프린스 챠밍.jpg >
# < 665 플라워 킬링 문.jpg >
# < 666 플래닛.jpg >
# < 667 플래시.jpg >
# < 668 플랜 75.jpg >
# < 669 플레인.jpg >
# < 670 플로라 앤 썬.jpg >
# < 671 피그.jpg >
# < 672 피는 물보다 진하다.jpg >
# < 673 핑크퐁 시네마 콘서트 2- 원더스타 콘서트 대작전.jpg >
# < 674 핑크퐁 시네마 콘서트3 - 진저브레드맨을 잡아라.jpg >
# < 675 하늘의 푸르름을 아는 사람이여.jpg >
# < 676 하우스 오브 구찌.jpg >
# < 677 한 남자.jpg >
# < 678 한산 리덕스.jpg >
# < 679 한산- 용의 출현.jpg >
# < 680 한여름밤의 재즈.jpg >
# < 681 항구의 니쿠코짱!.jpg >
# < 682 해시태그 시그네.jpg >
# < 683 해적- 도깨비 깃발.jpg >
# < 684 해탄적일천.jpg >
# < 685 해피 뉴 이어.jpg >
# < 686 헌트.jpg >
# < 687 헌티드 맨션.jpg >
# < 688 헝거게임- 노래하는 새와 뱀의 발라드.jpg >
# < 689 헤어질 결심.jpg >
# < 690 헤이지니&럭키강이 비밀의 문.jpg >
# < 691 홈그라운드.jpg >
# < 692 홈리스.jpg >
# < 693 화녀.jpg >
# < 694 화란.jpg >
# < 695 화사한 그녀.jpg >
# < 696 화이트 노이즈.jpg >
# < 697 힐마 아프 클린트 - 미래를 위한 그림.jpg >
# < 698 힙노틱.jpg >

# %%
data = pd.DataFrame(lst,
                   columns = ["movie_idx","movie_nm", "pstr_size", "temp_idx","chr", "len_chr","lc_1","lc_2","lc_3","lc_4","chrbox_size","box_rate"])
    
data.to_csv("/Users/jihoonlee/Desktop/ASAC/ML/MLproject/lst.csv", header=True, sep=',')
